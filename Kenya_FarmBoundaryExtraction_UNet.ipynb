# %% [markdown]
# # Automatic Farm Boundary Extraction using U-Net model
#
# ```
# This notebook shows step by step on training a U-Net model for automatic farm boundary extraction on Sentinel-2 Images.
#
# The data used in this training proces is the Trans Nzoia, Kenya Farm Boundary data obtained from manual digitation on Sentinel-2 Imagery as part of this project.
#
# The code used in this notebook are modified from https://github.com/resingm/field-boundary-delineation
# ```

# %%
from sklearn.model_selection import train_test_split
import os
import numpy as np
import rasterio as rio
import sys
import typing
from osgeo import gdal
import keras
import tensorflow as tf
from skimage import exposure

# Install patchify library for python
# !pip install patchify

# If using google colab, define dataset directory
# from google.colab import drive

# %%
# Provide the folder directory like below
BASE_PATH = "data"
INPUT_PATH = BASE_PATH + "/Classified Data/"
OUTPUT_PATH = BASE_PATH + "/Networks"
TRAIN_PATH = "/train"
VAL_PATH = "/val"
TEST_PATH = "/test"
IMAGE_PATH = "/Original"
LABEL_PATH = "/Classified"

INCLUDE_FOLDERS = ["TransNzoia_timeseries_separated"]


LEGEND = {
    0: 'Other',
    1: 'Field Boundary'
}

# %%
# ################################################################
# Loading input data
#
# Input data is loaded into two dictionaries:
#
# images: contains the 4-band images. The values are loaded as ints.
# labels: contains 3D arrays in which each pixel is assigned with
#         a label "0" = other and "1" = field boundary
#
# ################################################################

def key_generator(file_name):
    """Generates the key of a file based on the file name. The resulting key is
    a tuple of the province as string & the file number index as int,
    e.g. ("gelderland", 29)
    """
    file_name = file_name.lower()
    file_name = file_name.replace("classified_", "")
    file_name = file_name.replace("original_", "")
    file_name = file_name.replace(".tif", "")
    (province, index) = tuple(file_name.split("_"))
    index = int(index)
    return (province, index)

def normalize(
    array: np.ndarray
):
    """ normalise image to give a meaningful output """
    array_min, array_max = array.min(), array.max()
    return (array - array_min) / (array_max - array_min)

def gtiff_to_array(file_path):
    """Takes an image file path and returns a tif file as a 3-dimensional numpy array, width x height x bands."""
    #data = gdal.Open(file_path)
    data = rio.open(file_path)
    bd1_array = data.read(1) #BLUE
    bd2_array = data.read(2) #GREEN
    bd3_array = data.read(3) #RED
    bd4_array = data.read(4) #NIR
    b01_norm = normalize(bd1_array)
    b02_norm = normalize(bd2_array)
    b03_norm = normalize(bd3_array)
    b04_norm = normalize(bd4_array)
    #bands = [data.GetRasterBand(i+1).ReadAsArray() for i in range(data.RasterCount)]
    return np.dstack((b03_norm, b02_norm, b01_norm, b04_norm))

def gtiff_to_array_mask(file_path):
    """Takes a mask file path and returns a tif file as a 3-dimensional numpy array, width x height x bands."""
    data = rio.open(file_path)
    bd1_array = data.read(1)
    return bd1_array.reshape(256,256,1)

def transform_classification_image(input):
    """Takes the classification image input (in RGB format as 3D array) and
    creates a 2D array out of this. The innermost array expects either values of
    [0, 0, 0] of [255, 255, 255] since this is the colouring we assigned to the
    classified images.

    :param input: 3D input image (classification)
    :return: 2D array image with labels 1 for 'other' and 2 for 'field_boundaries'
    """

    # Out of the 3D input array it takes the "max" element out of the array
    # This will either be 0 or 255. This function is just called to transform
    # the 3D array to a 2D array.
    result = np.reshape(np.max(input, axis=2), (input.shape[0], input.shape[1], 1))

    # Now the array consists of pixels with values "0" or "255". We transform
    # each value, that is larger than 0 (i.e. 255) and assign the label "2" to
    # it. Each other element (i.e. 0) will get assigned the label "1".
    result = np.where(result > 0, 1, 0)
    return result

# Dictionaries which contain the input data
images_train = {}
labels_train = {}
images_val = {}
labels_val = {}
images_test = {}
labels_test = {}

# Iterate through defined folders and load all image data into the dictionaries
# image_data and label_data. Images can be accessed with (<province>, <index>)
for folder in INCLUDE_FOLDERS:
    original = INPUT_PATH + folder + TRAIN_PATH + IMAGE_PATH
    classified = INPUT_PATH + folder + TRAIN_PATH + LABEL_PATH
    for f in os.listdir(original):
        value = gtiff_to_array(original + "/" + f)
        key = key_generator(f)
        images_train[key] = value
    for f in os.listdir(classified):
        value = gtiff_to_array_mask(classified + "/" + f)

        # Transform the classification image from RGB to labels "1" and "2"
        # value = transform_classification_image(value)
        key = key_generator(f)
        labels_train[key] = value

    print(f"{folder} train image tiles: {len(os.listdir(original))}")
    print(f"{folder} train label tiles: {len(os.listdir(classified))}")

# validation
for folder in INCLUDE_FOLDERS:
    original = INPUT_PATH + folder + VAL_PATH + IMAGE_PATH
    classified = INPUT_PATH + folder + VAL_PATH + LABEL_PATH
    for f in os.listdir(original):
        value = gtiff_to_array(original + "/" + f)
        key = key_generator(f)
        images_val[key] = value
    for f in os.listdir(classified):
        value = gtiff_to_array_mask(classified + "/" + f)

        # Transform the classification image from RGB to labels "1" and "2"
        # value = transform_classification_image(value)
        key = key_generator(f)
        labels_val[key] = value

    print(f"{folder} validation image tiles: {len(os.listdir(original))}")
    print(f"{folder} validation label tiles: {len(os.listdir(classified))}")

# test
for folder in INCLUDE_FOLDERS:
    original = INPUT_PATH + folder + TEST_PATH + IMAGE_PATH
    classified = INPUT_PATH + folder + TEST_PATH + LABEL_PATH
    for f in os.listdir(original):
        value = gtiff_to_array(original + "/" + f)
        key = key_generator(f)
        images_test[key] = value
    for f in os.listdir(classified):
        value = gtiff_to_array_mask(classified + "/" + f)

        # Transform the classification image from RGB to labels "1" and "2"
        # value = transform_classification_image(value)
        key = key_generator(f)
        labels_test[key] = value

    print(f"{folder} test image tiles: {len(os.listdir(original))}")
    print(f"{folder} test label tiles: {len(os.listdir(classified))}")

print(f"Shape of sample image file: {list(images_train.values())[0].shape}")
print(f"Shape of sample label file: {list(labels_train.values())[0].shape}")
# Out:
# TransNzoia_timeseries_separated train image tiles: 182
# TransNzoia_timeseries_separated train label tiles: 182
# TransNzoia_timeseries_separated validation image tiles: 52
# TransNzoia_timeseries_separated validation label tiles: 52
# TransNzoia_timeseries_separated test image tiles: 39
# TransNzoia_timeseries_separated test label tiles: 39
# Shape of sample image file: (256, 256, 4)
# Shape of sample label file: (256, 256, 1)

# %%
# LOAD TRAINING, VALIDATION, AND TEST DATA INTO DICTIONARIES

# Entire set of keys
keys_train = set(images_train.keys())
keys_val = set(images_val.keys())
keys_test = set(images_test.keys())

# # Split key_set into x_train_keys and x_test_keys
# keys_train = set(random_generator.sample(keys, calculate_k(len(keys))))
# keys_test = keys - keys_train

# Generate dictionaries with training data
x_train_dict = { k : images_train[k] for k in keys_train }
y_train_dict = { k : labels_train[k] for k in keys_train }

# Generate dictionaries with validation data
x_val_dict = { k : images_val[k] for k in keys_val }
y_val_dict = { k : labels_val[k] for k in keys_val }

# Generate dictionaries with test data
x_test_dict = { k : images_test[k] for k in keys_test }
y_test_dict = { k : labels_test[k] for k in keys_test }


# Print key set of each set
print(x_train_dict.keys())
print(x_val_dict.keys())
print(x_test_dict.keys())
# Out:
# dict_keys([('transnzoia', 134), ('transnzoia', 27), ('transnzoia', 91), ('transnzoia', 36), ('transnzoia', 155), ('transnzoia', 100), ('transnzoia', 45), ('transnzoia', 164), ('transnzoia', 109), ('transnzoia', 54), ('transnzoia', 173), ('transnzoia', 118), ('transnzoia', 63), ('transnzoia', 182), ('transnzoia', 127), ('transnzoia', 20), ('transnzoia', 29), ('transnzoia', 93), ('transnzoia', 38), ('transnzoia', 157), ('transnzoia', 102), ('transnzoia', 47), ('transnzoia', 166), ('transnzoia', 111), ('transnzoia', 56), ('transnzoia', 175), ('transnzoia', 120), ('transnzoia', 129), ('transnzoia', 22), ('transnzoia', 86), ('transnzoia', 31), ('transnzoia', 150), ('transnzoia', 95), ('transnzoia', 40), ('transnzoia', 159), ('transnzoia', 104), ('transnzoia', 49), ('transnzoia', 168), ('transnzoia', 113), ('transnzoia', 58), ('transnzoia', 177), ('transnzoia', 122), ('transnzoia', 15), ('transnzoia', 79), ('transnzoia', 24), ('transnzoia', 143), ('transnzoia', 88), ('transnzoia', 33), ('transnzoia', 152), ('transnzoia', 97), ('transnzoia', 42), ('transnzoia', 161), ('transnzoia', 106), ('transnzoia', 51), ('transnzoia', 170), ('transnzoia', 115), ('transnzoia', 179), ('transnzoia', 8), ('transnzoia', 72), ('transnzoia', 17), ('transnzoia', 136), ('transnzoia', 81), ('transnzoia', 26), ('transnzoia', 145), ('transnzoia', 90), ('transnzoia', 35), ('transnzoia', 154), ('transnzoia', 99), ('transnzoia', 44), ('transnzoia', 163), ('transnzoia', 108), ('transnzoia', 172), ('transnzoia', 1), ('transnzoia', 65), ('transnzoia', 10), ('transnzoia', 74), ('transnzoia', 19), ('transnzoia', 138), ('transnzoia', 83), ('transnzoia', 28), ('transnzoia', 147), ('transnzoia', 92), ('transnzoia', 37), ('transnzoia', 156), ('transnzoia', 101), ('transnzoia', 165), ('transnzoia', 174), ('transnzoia', 3), ('transnzoia', 67), ('transnzoia', 12), ('transnzoia', 131), ('transnzoia', 76), ('transnzoia', 21), ('transnzoia', 140), ('transnzoia', 85), ('transnzoia', 30), ('transnzoia', 149), ('transnzoia', 94), ('transnzoia', 39), ('transnzoia', 158), ('transnzoia', 103), ('transnzoia', 167), ('transnzoia', 60), ('transnzoia', 5), ('transnzoia', 124), ('transnzoia', 69), ('transnzoia', 14), ('transnzoia', 133), ('transnzoia', 78), ('transnzoia', 23), ('transnzoia', 142), ('transnzoia', 87), ('transnzoia', 32), ('transnzoia', 151), ('transnzoia', 96), ('transnzoia', 160), ('transnzoia', 53), ('transnzoia', 117), ('transnzoia', 62), ('transnzoia', 181), ('transnzoia', 7), ('transnzoia', 126), ('transnzoia', 71), ('transnzoia', 16), ('transnzoia', 135), ('transnzoia', 80), ('transnzoia', 25), ('transnzoia', 144), ('transnzoia', 89), ('transnzoia', 153), ('transnzoia', 46), ('transnzoia', 110), ('transnzoia', 55), ('transnzoia', 119), ('transnzoia', 64), ('transnzoia', 9), ('transnzoia', 128), ('transnzoia', 73), ('transnzoia', 18), ('transnzoia', 137), ('transnzoia', 82), ('transnzoia', 146), ('transnzoia', 48), ('transnzoia', 112), ('transnzoia', 57), ('transnzoia', 176), ('transnzoia', 2), ('transnzoia', 121), ('transnzoia', 66), ('transnzoia', 11), ('transnzoia', 130), ('transnzoia', 75), ('transnzoia', 139), ('transnzoia', 84), ('transnzoia', 148), ('transnzoia', 41), ('transnzoia', 105), ('transnzoia', 50), ('transnzoia', 169), ('transnzoia', 114), ('transnzoia', 59), ('transnzoia', 178), ('transnzoia', 4), ('transnzoia', 123), ('transnzoia', 68), ('transnzoia', 13), ('transnzoia', 132), ('transnzoia', 77), ('transnzoia', 141), ('transnzoia', 34), ('transnzoia', 98), ('transnzoia', 43), ('transnzoia', 162), ('transnzoia', 107), ('transnzoia', 52), ('transnzoia', 171), ('transnzoia', 116), ('transnzoia', 61), ('transnzoia', 180), ('transnzoia', 6), ('transnzoia', 125), ('transnzoia', 70)])
# dict_keys([('transnzoia', 189), ('transnzoia', 192), ('transnzoia', 198), ('transnzoia', 195), ('transnzoia', 201), ('transnzoia', 204), ('transnzoia', 210), ('transnzoia', 207), ('transnzoia', 213), ('transnzoia', 219), ('transnzoia', 216), ('transnzoia', 222), ('transnzoia', 225), ('transnzoia', 231), ('transnzoia', 228), ('transnzoia', 234), ('transnzoia', 185), ('transnzoia', 191), ('transnzoia', 188), ('transnzoia', 194), ('transnzoia', 197), ('transnzoia', 203), ('transnzoia', 200), ('transnzoia', 206), ('transnzoia', 212), ('transnzoia', 209), ('transnzoia', 215), ('transnzoia', 218), ('transnzoia', 224), ('transnzoia', 221), ('transnzoia', 227), ('transnzoia', 230), ('transnzoia', 233), ('transnzoia', 184), ('transnzoia', 187), ('transnzoia', 193), ('transnzoia', 190), ('transnzoia', 196), ('transnzoia', 199), ('transnzoia', 205), ('transnzoia', 202), ('transnzoia', 208), ('transnzoia', 211), ('transnzoia', 217), ('transnzoia', 214), ('transnzoia', 220), ('transnzoia', 223), ('transnzoia', 229), ('transnzoia', 226), ('transnzoia', 232), ('transnzoia', 186), ('transnzoia', 183)])
# dict_keys([('transnzoia', 247), ('transnzoia', 253), ('transnzoia', 256), ('transnzoia', 262), ('transnzoia', 259), ('transnzoia', 265), ('transnzoia', 268), ('transnzoia', 271), ('transnzoia', 237), ('transnzoia', 243), ('transnzoia', 240), ('transnzoia', 246), ('transnzoia', 249), ('transnzoia', 255), ('transnzoia', 252), ('transnzoia', 258), ('transnzoia', 261), ('transnzoia', 267), ('transnzoia', 264), ('transnzoia', 270), ('transnzoia', 273), ('transnzoia', 236), ('transnzoia', 239), ('transnzoia', 242), ('transnzoia', 248), ('transnzoia', 245), ('transnzoia', 251), ('transnzoia', 257), ('transnzoia', 254), ('transnzoia', 260), ('transnzoia', 263), ('transnzoia', 269), ('transnzoia', 266), ('transnzoia', 272), ('transnzoia', 238), ('transnzoia', 235), ('transnzoia', 241), ('transnzoia', 244), ('transnzoia', 250)])

# %%
# ################################################################
# Visualize some sample input data
#
# Helps to verify that the data is correct and also supports the
# thinking process if trying to debug the program.
# ################################################################

from matplotlib import patches, pyplot


def visualize_labels(arr, title, legend_labels):
    """Visualize the labels prepared from the reference images.

    :param arr: 3D array of an image to display
    :param title: Title to assign to the output
    :param label: Labels to use in the legend
    """
    fig = pyplot.figure()

    a = fig.add_subplot(1, 1, 1)
    a.set_title(title)

    values = np.unique(arr.ravel())
    im = pyplot.imshow(arr[:, :, 0])

    # get the colors of the values according to the color map used by imshow
    colors = [im.cmap(im.norm(v)) for v in values]

    # Generate a legend
    legend = []
    for i, v in enumerate(values):
        legend.append(patches.Patch(
            color=colors[i],
            label=legend_labels[v]
        ))
    pyplot.legend(handles=legend, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )


def visualize_data(arr, title):
    """Visualize the satellite image data.

    :param arr: Input image (4 bands, the first 3 will be printed)
    :param title: Title of the plot
    """
    # Switching bands:
    #     blue green red
    #     red  green blue

    data = arr[:, :, 0:-1]
    # red = data[:, :, 0].copy()
    # data[:, :, 0] = data[:, :, 2]
    # data[:, :, 2] = red

    # Should be already the case if normalization is included
    data = data.astype(np.float32)

    # perform stretching for better visualization
    for i in range(data.shape[2]):
        p2, p98 = np.percentile(data[:, :, i], (2, 98))
        data[:, :, i] = exposure.rescale_intensity(data[:, :, i],
                                                      in_range=(p2, p98))
    fig = pyplot.figure()
    a=fig.add_subplot(1,1,1)
    a.set_title(title)
    pyplot.imshow(data)


key = list(x_train_dict.keys())[0]
print(key)
# key = ('overijssel', 17)
visualize_data(images_train[key], f"RGB image of {key}")
visualize_labels(labels_train[key], f"Classification of {key} ", LEGEND)
# Out:
# ('transnzoia', 134)

# %%
# Crop Images into smaller and uniform patch size for training purpose

from patchify import patchify

PATCHSIZE = 256
NBANDS = list(images_train.values())[0].shape[-1]

def perform_gridwise_sampling(img, patchsize):
    """Takes an input array with 3 dimensions and returns a 4 dimension array
    where the outermost dimension consists of patches out of the image.
    Patches are cut gridwise out of a grid with patchsize x patchsize pixels

    :param img: 3D input array of an image
    :param patchsize: The size of a patch
    :return: input image split into multiple patches in 4D array
    """
    #x = int(img.shape[0] / patchsize)
    #y = int(img.shape[1] / patchsize)
    n = img.shape[2]
    s = patchsize # to keep the code lines short

    patches_img = patchify(img, (s, s, n), step=s)

    patches = np.zeros(
        shape=(0, s, s, n),
        dtype=img.dtype
    )

    for row in range(patches_img.shape[0]):
        for col in range(patches_img.shape[1]):
            # create patch, expand the dimension and add it to the samples
            # patch = img[row * s : (row + 1) * s, col * s : (col + 1) * s, :]
            patch = patches_img[row, col, :, :]
            #patch = np.expand_dims(patch, axis=0)
            patches = np.concatenate((patches, patch), axis=0)

    return patches

# TRAINING DATA LOADER
x_train = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, NBANDS), dtype=np.float32)
y_train = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, 1), dtype=np.float32)


for k in x_train_dict.keys():
    # Create patches
    x_patches = perform_gridwise_sampling(x_train_dict[k], PATCHSIZE)
    y_patches = perform_gridwise_sampling(y_train_dict[k], PATCHSIZE)

    # Insert patches into x_train and y_train data set
    x_train = np.concatenate((x_train, x_patches), axis=0)
    y_train = np.concatenate((y_train, y_patches), axis=0)


# Print a sample set of the data set to verify, samples are created properly
sample_size = 1

while sample_size:
    visualize_data(x_train[sample_size], f"Training Patch sample {sample_size}")
    visualize_labels(y_train[sample_size], f"Training Patch sample {sample_size}", LEGEND)
    #print(x_train[sample_size].shape)
    #print(y_train[sample_size].shape)
    sample_size -= 1


# VALIDATION DATA LOADER
x_val = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, NBANDS), dtype=np.float32)
y_val = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, 1), dtype=np.float32)


for k in x_val_dict.keys():
    # Create patches
    x_patches = perform_gridwise_sampling(x_val_dict[k], PATCHSIZE)
    y_patches = perform_gridwise_sampling(y_val_dict[k], PATCHSIZE)

    # Insert patches into x_train and y_train data set
    x_val = np.concatenate((x_val, x_patches), axis=0)
    y_val = np.concatenate((y_val, y_patches), axis=0)

# Print a sample set of the data set to verify, samples are created properly
sample_size = 1

while sample_size:
    visualize_data(x_val[sample_size], f"Validation Patch sample {sample_size}")
    visualize_labels(y_val[sample_size], f"Validation Patch sample {sample_size}", LEGEND)
    #print(x_val[sample_size].shape)
    #print(y_val[sample_size].shape)
    sample_size -= 1

# %%
print("Number of training patches: ", len(x_train))
print("Number of validation patches: ", len(x_val))
# Out:
# Number of training patches:  182
# Number of validation patches:  52

# %% [markdown]
# # Model Training

# %%
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import models
from tensorflow.keras import metrics
from tensorflow.keras import optimizers

def conv_block(input_tensor, num_filters):
	encoder = layers.Conv2D(num_filters, (3, 3), padding='same')(input_tensor)
	encoder = layers.BatchNormalization()(encoder)
	encoder = layers.Activation('relu')(encoder)
	encoder = layers.Conv2D(num_filters, (3, 3), padding='same')(encoder)
	encoder = layers.BatchNormalization()(encoder)
	encoder = layers.Activation('relu')(encoder)
	return encoder

def encoder_block(input_tensor, num_filters):
	encoder = conv_block(input_tensor, num_filters)
	encoder_pool = layers.MaxPooling2D((2, 2), strides=(2, 2))(encoder)
	return encoder_pool, encoder

def decoder_block(input_tensor, concat_tensor, num_filters):
	decoder = layers.Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding='same')(input_tensor)
	decoder = layers.concatenate([concat_tensor, decoder], axis=-1)
	decoder = layers.BatchNormalization()(decoder)
	decoder = layers.Activation('relu')(decoder)
	decoder = layers.Conv2D(num_filters, (3, 3), padding='same')(decoder)
	decoder = layers.BatchNormalization()(decoder)
	decoder = layers.Activation('relu')(decoder)
	decoder = layers.Conv2D(num_filters, (3, 3), padding='same')(decoder)
	decoder = layers.BatchNormalization()(decoder)
	decoder = layers.Activation('relu')(decoder)
	return decoder

def get_model():
	inputs = layers.Input(shape=[None, None, num_channels]) # 256
	encoder0_pool, encoder0 = encoder_block(inputs, 32) # 128
	encoder1_pool, encoder1 = encoder_block(encoder0_pool, 64) # 64
	encoder2_pool, encoder2 = encoder_block(encoder1_pool, 128) # 32
	encoder3_pool, encoder3 = encoder_block(encoder2_pool, 256) # 16
	encoder4_pool, encoder4 = encoder_block(encoder3_pool, 512) # 8
	center = conv_block(encoder4_pool, 1024) # center
	decoder4 = decoder_block(center, encoder4, 512) # 16
	decoder3 = decoder_block(decoder4, encoder3, 256) # 32
	decoder2 = decoder_block(decoder3, encoder2, 128) # 64
	decoder1 = decoder_block(decoder2, encoder1, 64) # 128
	decoder0 = decoder_block(decoder1, encoder0, 32) # 256
	outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(decoder0)

	model = models.Model(inputs=[inputs], outputs=[outputs])

	model.compile(
		optimizer=optimizers.get(OPTIMIZER),
		loss=losses.get(LOSS),
		metrics=[metrics.get(metric) for metric in METRICS])

	return model

# %%
def learning_rate_scheduler(epoch):
    lr = 1e-4
    '''
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 150:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    '''
    print("Set Learning Rate : {}".format(lr))
    return lr

# %%
# Specify model training parameters.
num_channels = 4
BATCH_SIZE = 16
EPOCHS = 50
OPTIMIZER = optimizers.Adam()
LOSS = losses.BinaryCrossentropy()
METRICS = ['Precision', 'Recall']

# %%
# Define the model
model = get_model()
#model.summary()
# Out:
# 2023-06-30 06:00:14.270375: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.

# %%
checkpointer = tf.keras.callbacks.ModelCheckpoint('KE_unet.h5', verbose=1, save_best_only=True)
logger = tf.keras.callbacks.TensorBoard(log_dir='logs')

callbacks = [logger, checkpointer]

# %%
# load pre-trained model (UNet model trained on NL dataset)
model.load_weights('NL_unet_nl.h5')

# %%
history = model.fit(x=x_train, y=y_train,
                    validation_data=(x_val, y_val),
                    callbacks=callbacks,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS)
# Out:
# Epoch 1/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3068 - precision: 0.2553 - recall: 0.0541
# Epoch 1: val_loss improved from inf to 0.46415, saving model to KE_unet.h5
# 12/12 [==============================] - 113s 5s/step - loss: 0.3068 - precision: 0.2553 - recall: 0.0541 - val_loss: 0.4641 - val_precision: 0.1670 - val_recall: 6.1138e-04
# Epoch 2/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2521 - precision: 0.4161 - recall: 0.0012
# Epoch 2: val_loss did not improve from 0.46415
# 12/12 [==============================] - 13s 1s/step - loss: 0.2521 - precision: 0.4161 - recall: 0.0012 - val_loss: 0.6458 - val_precision: 0.2043 - val_recall: 0.0054
# Epoch 3/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2417 - precision: 0.4857 - recall: 0.0056
# Epoch 3: val_loss did not improve from 0.46415
# 12/12 [==============================] - 13s 1s/step - loss: 0.2417 - precision: 0.4857 - recall: 0.0056 - val_loss: 0.4809 - val_precision: 0.3260 - val_recall: 0.0340
# Epoch 4/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2362 - precision: 0.5027 - recall: 0.0079
# Epoch 4: val_loss improved from 0.46415 to 0.30406, saving model to KE_unet.h5
# 12/12 [==============================] - 19s 2s/step - loss: 0.2362 - precision: 0.5027 - recall: 0.0079 - val_loss: 0.3041 - val_precision: 0.3160 - val_recall: 0.1102
# Epoch 5/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2317 - precision: 0.5005 - recall: 0.0177
# Epoch 5: val_loss improved from 0.30406 to 0.29835, saving model to KE_unet.h5
# 12/12 [==============================] - 19s 2s/step - loss: 0.2317 - precision: 0.5005 - recall: 0.0177 - val_loss: 0.2983 - val_precision: 0.3465 - val_recall: 0.1111
# Epoch 6/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2283 - precision: 0.5218 - recall: 0.0186
# Epoch 6: val_loss improved from 0.29835 to 0.29363, saving model to KE_unet.h5
# 12/12 [==============================] - 19s 2s/step - loss: 0.2283 - precision: 0.5218 - recall: 0.0186 - val_loss: 0.2936 - val_precision: 0.3635 - val_recall: 0.1476
# Epoch 7/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2246 - precision: 0.5160 - recall: 0.0345
# Epoch 7: val_loss improved from 0.29363 to 0.28643, saving model to KE_unet.h5
# 12/12 [==============================] - 19s 2s/step - loss: 0.2246 - precision: 0.5160 - recall: 0.0345 - val_loss: 0.2864 - val_precision: 0.3997 - val_recall: 0.1379
# Epoch 8/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2215 - precision: 0.5209 - recall: 0.0437
# Epoch 8: val_loss did not improve from 0.28643
# 12/12 [==============================] - 13s 1s/step - loss: 0.2215 - precision: 0.5209 - recall: 0.0437 - val_loss: 0.2902 - val_precision: 0.4068 - val_recall: 0.1305
# Epoch 9/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2181 - precision: 0.5453 - recall: 0.0424
# Epoch 9: val_loss improved from 0.28643 to 0.27143, saving model to KE_unet.h5
# 12/12 [==============================] - 19s 2s/step - loss: 0.2181 - precision: 0.5453 - recall: 0.0424 - val_loss: 0.2714 - val_precision: 0.4346 - val_recall: 0.1048
# Epoch 10/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2146 - precision: 0.5498 - recall: 0.0544
# Epoch 10: val_loss improved from 0.27143 to 0.27039, saving model to KE_unet.h5
# 12/12 [==============================] - 18s 2s/step - loss: 0.2146 - precision: 0.5498 - recall: 0.0544 - val_loss: 0.2704 - val_precision: 0.4324 - val_recall: 0.1266
# Epoch 11/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2108 - precision: 0.5482 - recall: 0.0745
# Epoch 11: val_loss improved from 0.27039 to 0.25679, saving model to KE_unet.h5
# 12/12 [==============================] - 21s 2s/step - loss: 0.2108 - precision: 0.5482 - recall: 0.0745 - val_loss: 0.2568 - val_precision: 0.4451 - val_recall: 0.1028
# Epoch 12/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2076 - precision: 0.5629 - recall: 0.0821
# Epoch 12: val_loss did not improve from 0.25679
# 12/12 [==============================] - 14s 1s/step - loss: 0.2076 - precision: 0.5629 - recall: 0.0821 - val_loss: 0.2615 - val_precision: 0.4446 - val_recall: 0.1254
# Epoch 13/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2031 - precision: 0.5665 - recall: 0.1058
# Epoch 13: val_loss did not improve from 0.25679
# 12/12 [==============================] - 13s 1s/step - loss: 0.2031 - precision: 0.5665 - recall: 0.1058 - val_loss: 0.2611 - val_precision: 0.4361 - val_recall: 0.1473
# Epoch 14/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1990 - precision: 0.5706 - recall: 0.1274
# Epoch 14: val_loss improved from 0.25679 to 0.25285, saving model to KE_unet.h5
# 12/12 [==============================] - 18s 2s/step - loss: 0.1990 - precision: 0.5706 - recall: 0.1274 - val_loss: 0.2528 - val_precision: 0.4499 - val_recall: 0.0858
# Epoch 15/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1946 - precision: 0.5769 - recall: 0.1495
# Epoch 15: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1946 - precision: 0.5769 - recall: 0.1495 - val_loss: 0.2562 - val_precision: 0.4468 - val_recall: 0.1003
# Epoch 16/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1920 - precision: 0.5818 - recall: 0.1609
# Epoch 16: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1920 - precision: 0.5818 - recall: 0.1609 - val_loss: 0.2591 - val_precision: 0.4437 - val_recall: 0.0989
# Epoch 17/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1864 - precision: 0.5946 - recall: 0.1959
# Epoch 17: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1864 - precision: 0.5946 - recall: 0.1959 - val_loss: 0.2575 - val_precision: 0.4491 - val_recall: 0.0983
# Epoch 18/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1822 - precision: 0.5992 - recall: 0.2230
# Epoch 18: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1822 - precision: 0.5992 - recall: 0.2230 - val_loss: 0.2561 - val_precision: 0.4457 - val_recall: 0.1270
# Epoch 19/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1784 - precision: 0.6034 - recall: 0.2541
# Epoch 19: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1784 - precision: 0.6034 - recall: 0.2541 - val_loss: 0.2570 - val_precision: 0.4375 - val_recall: 0.1364
# Epoch 20/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1735 - precision: 0.6104 - recall: 0.2878
# Epoch 20: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1735 - precision: 0.6104 - recall: 0.2878 - val_loss: 0.2576 - val_precision: 0.4450 - val_recall: 0.0972
# Epoch 21/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1675 - precision: 0.6260 - recall: 0.3101
# Epoch 21: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1675 - precision: 0.6260 - recall: 0.3101 - val_loss: 0.2616 - val_precision: 0.4311 - val_recall: 0.1169
# Epoch 22/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1620 - precision: 0.6368 - recall: 0.3448
# Epoch 22: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1620 - precision: 0.6368 - recall: 0.3448 - val_loss: 0.2662 - val_precision: 0.4230 - val_recall: 0.1411
# Epoch 23/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1582 - precision: 0.6399 - recall: 0.3813
# Epoch 23: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1582 - precision: 0.6399 - recall: 0.3813 - val_loss: 0.2641 - val_precision: 0.4233 - val_recall: 0.1248
# Epoch 24/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1543 - precision: 0.6453 - recall: 0.4090
# Epoch 24: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1543 - precision: 0.6453 - recall: 0.4090 - val_loss: 0.2635 - val_precision: 0.4262 - val_recall: 0.1325
# Epoch 25/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1504 - precision: 0.6557 - recall: 0.4279
# Epoch 25: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1504 - precision: 0.6557 - recall: 0.4279 - val_loss: 0.2641 - val_precision: 0.4126 - val_recall: 0.1142
# Epoch 26/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1439 - precision: 0.6686 - recall: 0.4641
# Epoch 26: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1439 - precision: 0.6686 - recall: 0.4641 - val_loss: 0.2668 - val_precision: 0.4175 - val_recall: 0.1223
# Epoch 27/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1391 - precision: 0.6844 - recall: 0.4801
# Epoch 27: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1391 - precision: 0.6844 - recall: 0.4801 - val_loss: 0.2690 - val_precision: 0.3884 - val_recall: 0.1452
# Epoch 28/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1365 - precision: 0.6829 - recall: 0.5150
# Epoch 28: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1365 - precision: 0.6829 - recall: 0.5150 - val_loss: 0.2753 - val_precision: 0.3864 - val_recall: 0.1494
# Epoch 29/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1338 - precision: 0.6923 - recall: 0.5159
# Epoch 29: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1338 - precision: 0.6923 - recall: 0.5159 - val_loss: 0.2768 - val_precision: 0.3919 - val_recall: 0.1403
# Epoch 30/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1270 - precision: 0.7058 - recall: 0.5562
# Epoch 30: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1270 - precision: 0.7058 - recall: 0.5562 - val_loss: 0.2810 - val_precision: 0.3737 - val_recall: 0.1177
# Epoch 31/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1231 - precision: 0.7127 - recall: 0.5795
# Epoch 31: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1231 - precision: 0.7127 - recall: 0.5795 - val_loss: 0.2812 - val_precision: 0.3825 - val_recall: 0.1717
# Epoch 32/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1194 - precision: 0.7243 - recall: 0.5905
# Epoch 32: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1194 - precision: 0.7243 - recall: 0.5905 - val_loss: 0.2883 - val_precision: 0.3805 - val_recall: 0.1540
# Epoch 33/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1145 - precision: 0.7300 - recall: 0.6237
# Epoch 33: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1145 - precision: 0.7300 - recall: 0.6237 - val_loss: 0.2857 - val_precision: 0.3789 - val_recall: 0.1589
# Epoch 34/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1124 - precision: 0.7372 - recall: 0.6306
# Epoch 34: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1124 - precision: 0.7372 - recall: 0.6306 - val_loss: 0.2897 - val_precision: 0.3805 - val_recall: 0.1590
# Epoch 35/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1111 - precision: 0.7436 - recall: 0.6343
# Epoch 35: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1111 - precision: 0.7436 - recall: 0.6343 - val_loss: 0.2928 - val_precision: 0.3652 - val_recall: 0.1786
# Epoch 36/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1102 - precision: 0.7424 - recall: 0.6456
# Epoch 36: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1102 - precision: 0.7424 - recall: 0.6456 - val_loss: 0.2963 - val_precision: 0.3789 - val_recall: 0.1952
# Epoch 37/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1062 - precision: 0.7518 - recall: 0.6609
# Epoch 37: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.1062 - precision: 0.7518 - recall: 0.6609 - val_loss: 0.3067 - val_precision: 0.3748 - val_recall: 0.1623
# Epoch 38/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0997 - precision: 0.7683 - recall: 0.6862
# Epoch 38: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0997 - precision: 0.7683 - recall: 0.6862 - val_loss: 0.3089 - val_precision: 0.3684 - val_recall: 0.2041
# Epoch 39/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0983 - precision: 0.7654 - recall: 0.6991
# Epoch 39: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0983 - precision: 0.7654 - recall: 0.6991 - val_loss: 0.3155 - val_precision: 0.3711 - val_recall: 0.1822
# Epoch 40/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0975 - precision: 0.7671 - recall: 0.7020
# Epoch 40: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0975 - precision: 0.7671 - recall: 0.7020 - val_loss: 0.3162 - val_precision: 0.3623 - val_recall: 0.1798
# Epoch 41/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0939 - precision: 0.7836 - recall: 0.7053
# Epoch 41: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0939 - precision: 0.7836 - recall: 0.7053 - val_loss: 0.3129 - val_precision: 0.3421 - val_recall: 0.1803
# Epoch 42/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0932 - precision: 0.7842 - recall: 0.7114
# Epoch 42: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0932 - precision: 0.7842 - recall: 0.7114 - val_loss: 0.3193 - val_precision: 0.3411 - val_recall: 0.2116
# Epoch 43/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0892 - precision: 0.7865 - recall: 0.7371
# Epoch 43: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0892 - precision: 0.7865 - recall: 0.7371 - val_loss: 0.3284 - val_precision: 0.3558 - val_recall: 0.2049
# Epoch 44/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0857 - precision: 0.7978 - recall: 0.7462
# Epoch 44: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0857 - precision: 0.7978 - recall: 0.7462 - val_loss: 0.3328 - val_precision: 0.3414 - val_recall: 0.2087
# Epoch 45/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0799 - precision: 0.8119 - recall: 0.7665
# Epoch 45: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0799 - precision: 0.8119 - recall: 0.7665 - val_loss: 0.3415 - val_precision: 0.3493 - val_recall: 0.2017
# Epoch 46/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0769 - precision: 0.8193 - recall: 0.7772
# Epoch 46: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0769 - precision: 0.8193 - recall: 0.7772 - val_loss: 0.3472 - val_precision: 0.3392 - val_recall: 0.2020
# Epoch 47/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0765 - precision: 0.8200 - recall: 0.7796
# Epoch 47: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0765 - precision: 0.8200 - recall: 0.7796 - val_loss: 0.3429 - val_precision: 0.3410 - val_recall: 0.1855
# Epoch 48/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0761 - precision: 0.8215 - recall: 0.7823
# Epoch 48: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0761 - precision: 0.8215 - recall: 0.7823 - val_loss: 0.3498 - val_precision: 0.3440 - val_recall: 0.1824
# Epoch 49/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0733 - precision: 0.8316 - recall: 0.7872
# Epoch 49: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0733 - precision: 0.8316 - recall: 0.7872 - val_loss: 0.3536 - val_precision: 0.3317 - val_recall: 0.2101
# Epoch 50/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0761 - precision: 0.8151 - recall: 0.7924
# Epoch 50: val_loss did not improve from 0.25285
# 12/12 [==============================] - 13s 1s/step - loss: 0.0761 - precision: 0.8151 - recall: 0.7924 - val_loss: 0.3636 - val_precision: 0.3310 - val_recall: 0.2101

# %%
# Plot the training and validation loss at each epoch

import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the training and validation Precision at each epoch

p_scr = history.history['precision']
val_p_scr = history.history['val_precision']

plt.plot(epochs, p_scr, 'y', label='Training Precision Score')
plt.plot(epochs, val_p_scr, 'r', label='Validation Precision Score')
plt.title('Training and Validation Precision Score')
plt.xlabel('Epochs')
plt.ylabel('Precision Score')
plt.legend()
plt.show()

# %%
# Plot the training and validation Recall at each epoch

r_scr = history.history['recall']
val_r_scr = history.history['val_recall']

plt.plot(epochs, r_scr, 'y', label='Training Recall Score')
plt.plot(epochs, val_r_scr, 'r', label='Validation Recall Score')
plt.title('Training and Validation Recall Score')
plt.xlabel('Epochs')
plt.ylabel('Recall Score')
plt.legend()
plt.show()

# %%
# Restore the weights
model.load_weights('unet_nl_100ep_200623.h5')

# %%
# # cont. training
# # define the checkpoint
# filepath = "./nl_unet_model_600ep.h5"
# checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
# callbacks_list = [checkpoint]

# # fit the model
# model.fit(x_train, y_train, epochs=5, batch_size=50, callbacks=callbacks_list)

# %% [markdown]
# # Model Prediction/Testing

# %%
x_test = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, NBANDS), dtype=np.float32)
y_test = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, 1), dtype=np.float32)


for k in x_test_dict.keys():
    # Create patches
    x_patches = perform_gridwise_sampling(x_test_dict[k], PATCHSIZE)
    y_patches = perform_gridwise_sampling(y_test_dict[k], PATCHSIZE)

    # Insert patches into x_train and y_train data set
    x_test = np.concatenate((x_test, x_patches), axis=0)
    y_test = np.concatenate((y_test, y_patches), axis=0)


# visualize_data(x_test[1], f"Test patch sample {1}")
# visualize_labels(y_test[1], f"Test patch sample {1}", LEGEND)

# %%
# Predict on test dataset
y_pred = model.predict(np.expand_dims(x_test[0],0))
y_pred = np.squeeze(y_pred, axis=0)
result = np.where(y_pred > 0.5, 1, 0)

# Display Prediction
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(16, 7))

axs[0].imshow(x_test[0][:,:,[0,1,2]])
axs[0].set_title("Satellite Image")
axs[1].imshow(y_test[0])
axs[1].set_title("Groundtruth")
axs[2].imshow(result)
axs[2].set_title("Prediction")

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 5s 5s/step

# %%
# Evaluate the model
loss, acc = model.evaluate(x_test, y_test)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))

# %%
from keras.models import load_model
model = load_model("./nl_unet_model_100ep.h5")
